# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import pandas as pd

# %% [markdown]
# Import library
# 1. OpenCV = digunakan untuk pengolahan citra dan visi komputer.
# 2. Matplotlib = digunakan untuk visualisasi data dalam Python.
# 3. NumPy = digunakan untuk komputasi numerik.
# 4. Modul os = menyediakan fungsi-fungsi yang berinteraksi dengan sistem operasi.
# 5. Modul random = digunakan untuk menghasilkan bilangan acak.
# 6. Pandas = digunakan untuk analisis data struktural dalam Python.

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Data Augmentation

# %%
def resize_image(image, target_size=(150, 150)):
    return cv2.resize(image, target_size)

def rotate_image(image, angle):
    height, width = image.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((width/2, height/2), angle, 1)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
    return rotated_image

def shift_image(image, shift_x, shift_y):
    height, width = image.shape[:2]
    translation_matrix = np.float32([[1, 0, shift_x], [0, 1, shift_y]])
    shifted_image = cv2.warpAffine(image, translation_matrix, (width, height))
    return shifted_image

def zoom_image(image, scale):
    height, width = image.shape[:2]
    center_x, center_y = width // 2, height // 2
    scaled_width, scaled_height = int(width * scale), int(height * scale)
    start_x, start_y = center_x - scaled_width // 2, center_y - scaled_height // 2
    end_x, end_y = start_x + scaled_width, start_y + scaled_height
    zoomed_image = image[start_y:end_y, start_x:end_x]
    return zoomed_image

def flip_horizontal(image):
    return cv2.flip(image, 1)

def flip_vertical(image):
    return cv2.flip(image, 0)

input_folder = "C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger/finger_3"

image_files = [f for f in os.listdir(input_folder) if os.path.isfile(os.path.join(input_folder, f))]

num_images = 3

augmented_images = []

for file in image_files:
    image_path = os.path.join(input_folder, file)
    original_image = cv2.imread(image_path)
    for i in range(num_images):
            augmented_image = original_image.copy()

            augment_type = random.randint(1, 100)

            if 1 <= augment_type <= 20:
                angle = random.randint(-10, 10)
                augmented_image = rotate_image(augmented_image, angle)

            elif 21 <= augment_type <= 40:
                shift_x = random.randint(-10, 10)
                shift_y = random.randint(-10, 10)
                augmented_image = shift_image(augmented_image, shift_x, shift_y)

            elif 41 <= augment_type <= 60:
                scale = random.uniform(0.9, 1.1)
                augmented_image = zoom_image(augmented_image, scale)

            elif 61 <= augment_type <= 75:
                augmented_image = flip_horizontal(augmented_image)

            elif 76 <= augment_type <= 90:
                augmented_image = flip_vertical(augmented_image)

            elif 91 <= augment_type <= 100:
                angle = random.randint(-10, 10)
                augmented_image = rotate_image(augmented_image, angle)

                shift_x = random.randint(-10, 10)
                shift_y = random.randint(-10, 10)
                augmented_image = shift_image(augmented_image, shift_x, shift_y)

                scale = random.uniform(0.9, 1.1)
                augmented_image = zoom_image(augmented_image, scale)

                if random.random() < 0.5:
                    augmented_image = flip_horizontal(augmented_image)

                if random.random() < 0.5:
                    augmented_image = flip_vertical(augmented_image)

            augmented_image = resize_image(augmented_image)
            augmented_images.append(augmented_image)

augmented_images_array = np.array(augmented_images)

# %% [markdown]
# kode di atas merupakan proses data augmentasi yang berguna untuk membuat data lebih banyak dan bervariasi. Adapun fungsi fungsi yang digunakan dalam melakukan augmentasi data:
# 1. `resize_image`: Mengubah ukuran gambar sesuai dengan ukuran target yang diberikan.
# 2. `rotate_image`: Memutar gambar sebesar sudut yang ditentukan.
# 3. `shift_image`: Memindahkan gambar secara horizontal dan vertikal sesuai dengan nilai pergeseran yang diberikan.
# 4. `zoom_image`: Memperbesar atau memperkecil gambar sesuai dengan faktor skala yang diberikan.
# 5. `flip_horizontal` dan `flip_vertical`: Membalikkan gambar secara horizontal atau vertikal.
#
# langkah yang dilakukan untuk data augmentasi pertama mengiterasi melalui setiap file gambar dalam folder input.
# Untuk setiap gambar, kemudian membuat berapa banyak gambar diaugmentasi `num_images` dengan transformasi acak yang dipilih.
# Transformasi dipilih secara acak dengan menggunakan bilangan acak antara 1 dan 100 `augment_type`. Berbagai jenis augmentasi dipilih berdasarkan rentang nilai `augment_type`.
# Setiap gambar augmented kemudian diubah ukurannya menjadi ukuran yang ditentukan (default: 150x150) menggunakan fungsi `resize_image`.
# Gambar-gambar augmented disimpan dalam list `augmented_images`. Kemudian diubah menjadi array agar mudah di proses.

# %% [markdown]
# kode di bawah merupakan fungsi `show_images`digunakan untuk menampilkan gambar yang sudah di augmentasi. jumlah gambar yang ingin ditampilkan dapat diatur sesuai dengan `num_rows=10` dan `num_cols`

# %%
def show_images(images, num_rows=10, num_cols=5):
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(10,10))
    for i in range(num_rows):
        for j in range(num_cols):
            axes[i, j].imshow(cv2.cvtColor(images[i * num_cols + j], cv2.COLOR_BGR2RGB))
            axes[i, j].axis('off')
    plt.show()

show_images(augmented_images)

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# kode di bawah melakukan proses preprcessing. Pertama dengan menggunakan library cv2 untuk melakukan denoise dan proses spesifikasi dengan cara menerapkan modul GaussianBlur untuk denoise dan menghitung cdf untuk melakukan spesifikasi. Kemudian membuat list gambar yang sudah di proses dengan nama `processed_images`, melakukan perulangan pda gambar yang sudah di augmentasi `augmented_images_array` untuk melakukan denoise dan spesifikasi pada semua gambar kemudian di masukkan ke dalam list `processed_images`. Kemudian menampilkan gambar yang sudah di proses dengan fungsi `show_images`

# %%
def denoise_image(image):
    return cv2.GaussianBlur(image, (5, 5), 0)

def histogram_specification(image, reference_histogram):
    hist_image, _ = np.histogram(image.flatten(), 256, [0, 256])

    cdf_image = hist_image.cumsum()
    cdf_image_normalized = cdf_image * hist_image.max() / cdf_image.max()

    cdf_reference = reference_histogram.cumsum()
    cdf_reference_normalized = cdf_reference * hist_image.max() / cdf_reference.max()

    lut = np.interp(cdf_image_normalized, cdf_reference_normalized, range(256))

    transformed_image = lut[image]

    return transformed_image.astype(np.uint8)

reference_image = cv2.imread("refrence.jpg")
reference_hist, _ = np.histogram(reference_image.flatten(), 256, [0, 256])

processed_images = []

for image in augmented_images_array:
    denoised_image = denoise_image(image)
    spek_image = histogram_specification(denoised_image, reference_hist)
    
    processed_images.append(spek_image)

processed_images_array = np.array(processed_images)


show_images(processed_images)

# %% [markdown]
# ### Feature Extraction

# %%
def calculate_glcm(image, distances, angles):
    max_gray_level = 256
    glcm = np.zeros((max_gray_level, max_gray_level, len(distances), len(angles)), dtype=np.float64)
    
    for distance_index, distance in enumerate(distances):
        for angle_index, angle in enumerate(angles):
            for i in range(image.shape[0]):
                for j in range(image.shape[1]):
                    row_offset = int(np.round(np.sin(angle) * distance))
                    col_offset = int(np.round(np.cos(angle) * distance))
                    row = i + row_offset
                    col = j + col_offset
                    if row >= 0 and row < image.shape[0] and col >= 0 and col < image.shape[1]:
                        current_pixel = image[i, j]
                        neighbor_pixel = image[row, col]
                        glcm[current_pixel, neighbor_pixel, distance_index, angle_index] += 1
    
    glcm_sum = glcm.sum(axis=(0, 1), keepdims=True)
    glcm = glcm / glcm_sum
    return glcm

def calculate_glcm_properties(glcm):
    num_levels = glcm.shape[0]
    num_distances = glcm.shape[2]
    num_angles = glcm.shape[3]
    
    contrast = np.zeros((num_distances, num_angles))
    dissimilarity = np.zeros((num_distances, num_angles))
    homogeneity = np.zeros((num_distances, num_angles))
    energy = np.zeros((num_distances, num_angles))
    correlation = np.zeros((num_distances, num_angles))
    asm = np.zeros((num_distances, num_angles))
    entropy = np.zeros((num_distances, num_angles))
    
    for d in range(num_distances):
        for a in range(num_angles):
            glcm_slice = glcm[:, :, d, a]
            i, j = np.indices(glcm_slice.shape)
            
            contrast[d, a] = np.sum((i - j) ** 2 * glcm_slice)
            dissimilarity[d, a] = np.sum(np.abs(i - j) * glcm_slice)
            homogeneity[d, a] = np.sum(glcm_slice / (1 + np.abs(i - j)))
            energy[d, a] = np.sum(glcm_slice ** 2)
            asm[d, a] = energy[d, a]
            
            mean_i = np.sum(i * glcm_slice)
            mean_j = np.sum(j * glcm_slice)
            std_i = np.sqrt(np.sum((i - mean_i) ** 2 * glcm_slice))
            std_j = np.sqrt(np.sum((j - mean_j) ** 2 * glcm_slice))
            
            if std_i > 0 and std_j > 0:
                correlation[d, a] = np.sum((i - mean_i) * (j - mean_j) * glcm_slice) / (std_i * std_j)
            else:
                correlation[d, a] = 0
                
            entropy[d, a] = -np.sum(glcm_slice * np.log2(glcm_slice + (glcm_slice == 0)))
    
    return contrast, dissimilarity, homogeneity, energy, correlation, asm, entropy

features = []

angles = [0, 45, 90, 135]
distances = [1]

for idx, image in enumerate(processed_images):
    glcm = calculate_glcm(image, distances, angles)

    contrast, dissimilarity, homogeneity, energy, correlation, asm, entropy = calculate_glcm_properties(glcm)
    
    feature = {'image_index': idx}
    for angle_index, angle in enumerate([0, 45, 90, 135]):
        feature[f'contrast_{angle}'] = contrast[0, angle_index]
        feature[f'dissimilarity_{angle}'] = dissimilarity[0, angle_index]
        feature[f'homogeneity_{angle}'] = homogeneity[0, angle_index]
        feature[f'energy_{angle}'] = energy[0, angle_index]
        feature[f'correlation_{angle}'] = correlation[0, angle_index]
        feature[f'asm_{angle}'] = asm[0, angle_index]
        feature[f'entropy_{angle}'] = entropy[0, angle_index]
    
    features.append(feature)

features_df = pd.DataFrame(features)

output_csv_path = "csv_finger3/glcm_finger_3.csv"
features_df.to_csv(output_csv_path, index=False)

print(f"Fitur GLCM selesai diekstraksi")
# Out:
# Fitur GLCM selesai diekstraksi

# %% [markdown]
# Kode di atas melakukan ekstraksi fitur GLCM (Gray-Level Co-occurrence Matrix) dari gambar-gambar yang telah diproses sebelumnya.
#
# 1. Fungsi `calculate_glcm`:
# Fungsi ini menghitung matriks GLCM dari sebuah gambar. Matriks GLCM dihitung untuk setiap jarak `distance` dan sudut `angle` yang ditentukan. Untuk setiap piksel dalam gambar, diformulasikan jarak `row_offset` dan `col_offset` dan koordinat piksel tetangga yang sesuai. Piksel dan tetangga tersebut digunakan untuk mengupdate nilai GLCM. Hasil GLCM dinormalisasi dengan jumlah total entri dalam matriks.
#
# 2. Fungsi `calculate_glcm_properties`:
# Fungsi ini menghitung berbagai properti statistik dari matriks GLCM yang dihasilkan. Properti yang dihitung meliputi kontras, disimilaritas, homogenitas, energi, korelasi, ASM (Angular Second Moment), dan entropi.
# Setiap properti dihitung untuk setiap jarak dan sudut.
#
# 3. Loop untuk Ekstraksi Fitur:
# Skrip ini melakukan loop melalui setiap gambar yang telah diproses sebelumnya. Untuk setiap gambar, matriks GLCM dihitung menggunakan fungsi calculate_glcm.
# Properti GLCM diekstraksi menggunakan fungsi calculate_glcm_properties. Hasil fitur disimpan dalam sebuah list features.
#
# 4. Konversi ke DataFrame:
# Hasil fitur disimpan dalam bentuk DataFrame menggunakan `pd.DataFrame`. DataFrame ini kemudian disimpan dalam format CSV. Dengan cara ini, skrip ini menghasilkan dataset fitur GLCM yang dapat digunakan untuk melatih model pembelajaran mesin dalam berbagai tugas analisis citra atau pengenalan pola.

# %% [markdown]
# ### Features Selection

# %%
features_df = pd.read_csv("csv_finger3/glcm_finger_3.csv")

variance_threshold = 0.29
correlation_threshold = 0.8

variances = features_df.var()
selected_features_variance = variances[variances > variance_threshold].index
features_df_variance = features_df[selected_features_variance]

corr_matrix = features_df_variance.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

to_drop = [column for column in upper.columns if any(upper[column] > correlation_threshold)]
features_df_correlation = features_df_variance.drop(columns=to_drop)

output_csv_path_selected = "csv_finger3/glcm_features_selected_finger_3l.csv"
features_df_correlation.to_csv(output_csv_path_selected, index=False)

# %% [markdown]
# Kode di atas memuat DataFrame yang berisi fitur GLCM dari file CSV yang sebelumnya telah disimpan, kemudian melakukan seleksi fitur berdasarkan ambang batas varians dan ambang batas korelasi.
#
# 1. Seleksi Fitur Berdasarkan Varians:
# Varians dari setiap fitur dihitung menggunakan features_df.var(). Fitur yang memiliki varians di atas ambang batas (variance_threshold) dipilih. DataFrame baru features_df_variance dibuat hanya dengan fitur-fitur yang dipilih.
#
# 2. Seleksi Fitur Berdasarkan Korelasi:
# Matriks korelasi absolut dihitung menggunakan features_df_variance.corr().abs(). Bagian atas matriks korelasi diambil menggunakan np.triu(np.ones(corr_matrix.shape), k=1), karena matriks korelasi adalah simetris. Fitur-fitur yang memiliki korelasi di atas ambang batas (correlation_threshold) dengan fitur lainnya diidentifikasi dan dihapus. DataFrame baru features_df_correlation dibuat hanya dengan fitur-fitur yang dipilih setelah seleksi korelasi.
#
# Terakhir menyimpan DataFrame yang Dipilih. Dengan melakukan dua tahap seleksi fitur yang memungkinkan untuk mengurangi dimensi dari dataset fitur GLCM dan menghilangkan fitur-fitur yang memiliki korelasi tinggi dengan fitur lainnya.

# %% [markdown]
# ### Splitting Data

# %%
features_df = pd.read_csv("csv_finger3/glcm_features_selected_finger_3l.csv")

features = features_df.drop(columns=['image_index'])
labels = features_df['image_index']

data_combined = features.copy()
data_combined['label'] = labels

data_combined = data_combined.sample(frac=1, random_state=42).reset_index(drop=True)

train_ratio = 0.8
train_size = int(len(data_combined) * train_ratio)

train_data = data_combined[:train_size]
test_data = data_combined[train_size:]

X_train = train_data.drop(columns=['label'])
y_train = train_data['label']
X_test = test_data.drop(columns=['label'])
y_test = test_data['label']

X_train.to_csv("csv_finger3/X_train_3.csv", index=False)
X_test.to_csv("csv_finger3/X_test_3.csv", index=False)
y_train.to_csv("csv_finger3/y_train_3.csv", index=False)
y_test.to_csv("csv_finger3/y_test_3.csv", index=False)

print("Data telah selesai dibagi")
# Out:
# Data telah selesai dibagi

# %% [markdown]
# Pada kode di atas merupakan kode yang berfokus pada pemisahan data menjadi data latih dan data uji untuk keperluan pelatihan dan evaluasi model.
#
# 1. Memuat Data dari File CSV:
# DataFrame features_df dimuat dari file CSV yang berisi fitur GLCM yang telah dipilih sebelumnya.
#
# 2. Pemisahan Fitur dan Label:
# Fitur-fitur (kolom-kolom kecuali 'image_index') dan label (kolom 'image_index') dipisahkan ke dalam dua DataFrame terpisah. DataFrame features berisi fitur-fitur, sementara labels berisi label gambar (indeks gambar).
#
# 3. Penggabungan Data dan Pengacakan:
# Fitur-fitur dan label-label digabungkan menjadi satu DataFrame dengan menambahkan kolom 'label' yang berisi label-label.
# Data diacak dengan menggunakan metode .sample(frac=1) untuk memastikan bahwa data teracak dengan baik. Pengacakan dilakukan dengan menggunakan random_state=42 untuk menghasilkan hasilnya.
#
# 4. Pemisahan Data Latih dan Data Uji:
# Ukuran data latih ditentukan berdasarkan rasio yang telah ditetapkan sebelumnya (train_ratio), dan data uji akan menjadi sisa data setelah data latih diambil. DataFrame dipecah menjadi train_data dan test_data berdasarkan ukuran data latih yang telah ditentukan sebelumnya.
#
# 5. Pemisahan Fitur dan Label untuk Data Latih dan Data Uji:
# DataFrame-dataFrame yang telah dipisahkan (train_data dan test_data) kemudian dibagi lagi menjadi fitur (X) dan label (y) untuk data latih dan data uji. Dan yang terakhir menyimpan Data sebagai File CSV
#
# Dengan langkah-langkah yang sudah dilakukan, data telah disiapkan untuk digunakan dalam pelatihan dan evaluasi model.

# %% [markdown]
# ### Normalization

# %%
X_train = pd.read_csv("csv_finger3/X_train_3.csv")
X_test = pd.read_csv("csv_finger3/X_test_3.csv")
y_train = pd.read_csv("csv_finger3/y_train_3.csv")
y_test = pd.read_csv("csv_finger3/y_test_3.csv")


def min_max_scaling(df):
    return (df - df.min()) / (df.max() - df.min())

X_train_normalized = min_max_scaling(X_train)
X_test_normalized = min_max_scaling(X_test)
y_train_normalized = min_max_scaling(y_train)
y_test_normalized = min_max_scaling(y_test)

X_train_normalized.to_csv("csv_finger3/X_train_normalized_3.csv", index=False)
X_test_normalized.to_csv("csv_finger3/X_test_normalized_3.csv", index=False)
y_train_normalized.to_csv("csv_finger3/y_train_normalized_3.csv", index=False)
y_test_normalized.to_csv("csv_finger3/y_test_normalized_3.csv", index=False)

print("Data telah selesai dinormalisasi")
# Out:
# Data telah selesai dinormalisasi

# %% [markdown]
# Dalam bagian ini, kode melakukan normalisasi data menggunakan metode Min-Max Scaling sebelum menyimpannya kembali ke file CSV.
# 1. Memuat Data dari File CSV:
# DataFrame X_train, X_test, y_train, dan y_test dimuat dari file CSV yang sesuai.
#
# 2. Fungsi Min-Max Scaling:
# Fungsi `min_max_scaling` didefinisikan untuk melakukan normalisasi Min-Max Scaling pada DataFrame yang diberikan. Normalisasi Min-Max Scaling dilakukan dengan mengurangi nilai minimum dari setiap kolom dan membagi hasilnya dengan selisih nilai maksimum dan minimum dari setiap kolom. Ini akan menghasilkan nilai antara 0 dan 1.
#
# 3. Normalisasi Data:
# Setiap DataFrame di-normalisasi menggunakan fungsi `min_max_scaling`. X_train, X_test, y_train, dan y_test dinormalisasi masing-masing.
#
# Terakhir menyimpan Data yang Dinormalisasi sebagai File CSV. Dengan normalisasi ini, setiap fitur dan label telah diubah sehingga nilainya berada dalam rentang yang seragam, memudahkan proses pelatihan model dan mencegah dominasi fitur-fitur dengan skala yang besar.

# %% [markdown]
# ## Modeling

# %%
X_train = pd.read_csv("csv_finger3/X_train_normalized_3.csv").values
X_test = pd.read_csv("csv_finger3/X_test_normalized_3.csv").values
y_train = pd.read_csv("csv_finger3/y_train_normalized_3.csv").values.flatten()
y_test = pd.read_csv("csv_finger3/y_test_normalized_3.csv").values.flatten()

def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

def knn(X_train, y_train, X_test, k=3):
    predictions = []
    for test_point in X_test:
        distances = []
        for i, train_point in enumerate(X_train):
            distance = euclidean_distance(test_point, train_point)
            distances.append((distance, y_train[i]))
        distances.sort(key=lambda x: x[0])
        neighbors = distances[:k]
        neighbor_labels = [label for _, label in neighbors]
        most_common_label = max(set(neighbor_labels), key=neighbor_labels.count)
        predictions.append(most_common_label)
    return predictions

k = 10

y_pred = knn(X_train, y_train, X_test, k)

print("Modeling selesai.")
# Out:
# Modeling selesai.

# %% [markdown]
# Kode di atas mengimplementasikan algoritma k-Nearest Neighbors (k-NN) untuk klasifikasi data yang telah dinormalisasi sebelumnya.
#
# 1. Memuat Data dari File CSV yang Telah Dinormalisasi:
# DataFrame yang telah dinormalisasi sebelumnya dimuat dari file CSV dan diubah menjadi array NumPy.
#
# 2. Membuat fungsi Euclidean Distance:
# Fungsi `euclidean_distance` didefinisikan untuk menghitung jarak Euclidean antara dua titik dalam ruang fitur.
#
# 3. Algoritma k-NN:
# Fungsi knn diimplementasikan untuk melakukan klasifikasi dengan algoritma k-NN. Untuk setiap titik uji dalam X_test, jarak Euclidean dihitung terhadap semua titik latih dalam X_train. Jarak-jarak dan label-labelnya disimpan dalam sebuah list distances. List distances diurutkan berdasarkan jarak, dan k-nearest neighbors (k tetangga terdekat) diambil. Label-label dari k tetangga terdekat diambil, dan label yang paling umum di antara mereka dipilih sebagai prediksi untuk titik uji tersebut.
#
# Terakhir, fungsi knn dipanggil dengan parameter X_train, y_train, X_test, dan nilai k yang telah ditentukan sebelumnya. Hasil prediksi disimpan dalam y_pred.
# Dengan ini,telah dilakukan mplementasi dan penggunaan algoritma k-NN untuk melakukan klasifikasi pada dataset yang telah disiapkan.

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Kode dibawah mendefinisikan dua fungsi untuk mengevaluasi kinerja model klasifikasi:
#
# 1. Fungsi accuracy:
# Fungsi ini menghitung akurasi dari prediksi model. Akurasi didefinisikan sebagai jumlah prediksi yang benar dibagi dengan total jumlah prediksi.
#
# 2. Fungsi classification_report:
# Fungsi ini menghasilkan laporan klasifikasi yang mencakup metrik evaluasi seperti presisi (precision), recall, dan F1-score untuk setiap kelas, serta metrik rata-rata tertimbang (weighted average) dari presisi, recall, dan F1-score.
#
# Untuk setiap kelas,
# presisi dihitung sebagai rasio true positive dibagi dengan jumlah true positive dan false positive. Presisi mengukur seberapa akurat model dalam mengidentifikasi kelas positif.
#
# Recall dihitung sebagai rasio true positive dibagi dengan jumlah true positive dan false negative. Recall mengukur seberapa baik model dalam menangkap semua instance dari kelas yang benar positif.
#
# F1-score dihitung sebagai rasio harmonis dari presisi dan recall.
# Metrik-metrik ini dihitung untuk setiap kelas dalam data, dan juga dihitung nilai rata-rata tertimbang dari metrik-metrik tersebut untuk semua kelas.
#
# support digunakan menghitung jumlah instance dalam kelas yang diprediksi sebagai positif (true positive + false positive).
#
# Hasil laporan klasifikasi disusun dalam bentuk dictionary.
#
# Terakhir fungsi fungsi tersebut digunakan untuk mengevaluasi prediksi yang dihasilkan oleh model k-NN. Hasil evaluasi, termasuk akurasi dan laporan klasifikasi, kemudian dicetak.

# %%
def accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / len(y_true)

def classification_report(y_true, y_pred):
    labels = np.unique(y_true)
    report = {}
    for label in labels:
        true_positive = np.sum((y_true == label) & (y_pred == label))
        false_positive = np.sum((y_true != label) & (y_pred == label))
        false_negative = np.sum((y_true == label) & (y_pred != label))
        true_negative = np.sum((y_true != label) & (y_pred != label))
        
        precision = true_positive / (true_positive + false_positive) if (true_positive + false_positive) > 0 else 0
        recall = true_positive / (true_positive + false_negative) if (true_positive + false_negative) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        
        support = np.sum(y_true == label)
        
        report[label] = {
            "precision": precision,
            "recall": recall,
            "f1_score": f1_score,
            "support": support
        }
    
    avg_precision = np.sum([report[label]['precision'] * report[label]['support'] for label in labels]) / len(y_true)
    avg_recall = np.sum([report[label]['recall'] * report[label]['support'] for label in labels]) / len(y_true)
    avg_f1_score = np.sum([report[label]['f1_score'] * report[label]['support'] for label in labels]) / len(y_true)
    
    report['weighted avg'] = {
        "precision": avg_precision,
        "recall": avg_recall,
        "f1_score": avg_f1_score,
        "support": len(y_true)
    }
    
    return report

acc = accuracy(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Akurasi: {acc}")
print("Classification Report:")
for label, metrics in report.items():
    print(f"Label {label}:")
    for metric, value in metrics.items():
        print(f"  {metric}: {value:.2f}")

print("Evaluasi selesai.")
# Out:
# Akurasi: 0.0
# Classification Report:
# Label 0.0:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0054517133956386:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0093457943925233:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0101246105919003:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0116822429906542:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0147975077881619:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0155763239875389:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0194704049844236:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0257009345794392:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.02803738317757:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0303738317757009:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0404984423676012:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0490654205607476:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0669781931464174:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0700934579439252:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.073208722741433:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0755451713395638:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0794392523364486:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0864485981308411:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0934579439252336:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0942367601246105:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1004672897196261:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1035825545171339:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1105919003115264:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1129283489096573:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1160436137071651:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.116822429906542:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.117601246105919:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1214953271028037:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1238317757009345:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1246105919003115:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1285046728971962:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1440809968847352:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1448598130841121:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.146417445482866:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1526479750778816:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1549844236760124:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1557632398753894:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1565420560747663:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1588785046728972:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1596573208722741:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.160436137071651:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1674454828660436:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1697819314641744:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1744548286604361:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1775700934579439:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1783489096573208:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1869158878504672:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.190809968847352:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1954828660436137:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1962616822429906:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2032710280373831:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2087227414330218:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2141744548286604:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2165109034267912:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.219626168224299:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2235202492211838:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2274143302180685:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2289719626168224:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2445482866043613:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2461059190031152:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2562305295950156:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2616822429906542:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2663551401869158:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2679127725856697:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.293613707165109:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2943925233644859:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2982866043613707:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2990654205607476:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3006230529595015:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3037383177570093:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3045171339563863:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.308411214953271:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3107476635514019:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3115264797507788:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3123052959501557:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3130841121495327:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3154205607476635:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3247663551401869:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3395638629283489:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3426791277258567:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3512461059190031:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3535825545171339:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3566978193146417:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3598130841121495:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3621495327102804:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3644859813084112:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.366822429906542:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3683800623052959:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3699376947040498:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3761682242990654:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3792834890965732:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.382398753894081:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3901869158878505:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3948598130841121:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3956386292834891:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.396417445482866:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4018691588785046:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4042056074766355:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4073208722741433:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4197819314641745:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4244548286604361:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4275700934579439:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4322429906542056:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4369158878504673:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4376947040498442:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4384735202492212:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4392523364485981:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4485981308411215:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.455607476635514:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4602803738317757:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4665109034267913:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4727414330218069:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4758566978193146:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.484423676012461:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4875389408099688:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4914330218068536:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4968847352024922:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4976635514018692:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4984423676012461:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4992211838006231:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5015576323987538:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5023364485981309:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5031152647975078:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5038940809968847:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5116822429906542:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5124610591900312:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5155763239875389:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5295950155763239:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5311526479750779:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5334890965732088:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5342679127725857:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5428348909657321:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.543613707165109:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5459501557632399:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5514018691588785:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.559190031152648:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5638629283489096:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5669781931464174:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5771028037383178:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5809968847352025:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5817757009345794:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5825545171339563:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5841121495327103:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5934579439252337:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5957943925233645:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5981308411214953:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.602803738317757:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6035825545171339:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6059190031152648:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6152647975077882:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.617601246105919:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.618380062305296:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6199376947040498:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6222741433021807:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6253894080996885:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6261682242990654:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6339563862928349:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6386292834890965:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6464174454828661:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6495327102803738:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6534267912772586:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6643302180685359:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6658878504672897:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6690031152647975:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6713395638629284:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.676791277258567:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.677570093457944:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6822429906542056:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6830218068535826:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6845794392523364:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6869158878504673:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6931464174454829:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6970404984423676:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6978193146417445:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7102803738317757:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7219626168224299:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7227414330218068:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7398753894080997:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7422118380062306:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7429906542056075:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7437694704049844:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7445482866043613:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7461059190031153:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7468847352024922:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7562305295950156:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7585669781931464:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7632398753894081:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7741433021806854:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7873831775700935:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7889408099688473:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7904984423676013:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7912772585669782:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7928348909657321:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.793613707165109:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.794392523364486:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7975077881619937:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7998442367601246:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.807632398753894:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8123052959501558:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8130841121495327:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8177570093457944:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8216510903426791:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.82398753894081:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8247663551401869:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8278816199376947:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8333333333333334:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8372274143302181:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8419003115264797:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8434579439252337:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8450155763239875:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8465732087227414:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8473520249221184:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8520249221183801:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8574766355140186:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8590342679127726:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8629283489096573:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.867601246105919:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8738317757009346:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8761682242990654:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8785046728971962:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8792834890965732:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.882398753894081:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8839563862928349:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8886292834890965:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8940809968847352:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8964174454828661:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8979750778816199:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9018691588785048:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9042056074766356:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9088785046728972:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.910436137071651:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9158878504672896:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9166666666666666:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9182242990654206:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9213395638629284:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9221183800623052:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9228971962616822:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9252336448598132:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.926791277258567:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9306853582554516:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9330218068535826:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9439252336448598:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9454828660436138:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9470404984423676:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9493769470404984:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9501557632398754:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9509345794392524:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9532710280373832:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9548286604361372:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9587227414330218:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9633956386292836:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9641744548286604:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9805295950155763:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9828660436137072:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.983644859813084:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9914330218068536:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9937694704049844:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9992211838006232:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 1.0:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label weighted avg:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 260.00
# Evaluasi selesai.
