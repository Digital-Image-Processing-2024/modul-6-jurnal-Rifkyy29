# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import pandas as pd

# %% [markdown]
# ## Data Loading

# %%
base_folder = 'C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger'

def resize_image(img_path, size=(150, 150)):
    img = cv2.imread(img_path)
    if img is not None:
        resized_img = cv2.resize(img, size, interpolation=cv2.INTER_AREA)
        cv2.imwrite(img_path, resized_img)

def process_folders(base_folder, size=(150, 150)):
    for root, _, files in os.walk(base_folder):
        for filename in files:
            if filename.endswith(('.png', '.jpg', '.jpeg')):
                img_path = os.path.join(root, filename)
                resize_image(img_path, size)
                print(f'Resized image: {img_path}')

process_folders(base_folder)
print('Resizing completed for all images.')
# Out:
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D022016_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D022016_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D022016_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D022044_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D022044_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D022044_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D022069_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D022069_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D022069_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_f1d022103_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_f1d022103_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_f1d022103_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_f1d022120_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_f1d022120_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_f1d022120_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_f1d022149_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_f1d022149_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_f1d022149_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D022154_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D022154_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D022154_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D22320026_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D22320026_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\01_F1D22320026_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D020096_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D020096_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D020096_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_f1d022020_1_1.png
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_f1d022020_1_2.png
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_f1d022020_1_3.png
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D022028_1_1.png
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D022028_1_2.png
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D022028_1_3.png
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D022047_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D022047_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D022047_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D022099_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D022099_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D022099_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D022124_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D022124_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_F1D022124_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_f1d022164_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_f1d022164_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\02_f1d022164_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_F1D022008_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_F1D022008_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_F1D022008_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_F1D022036_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_F1D022036_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_F1D022036_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_F1D022040_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_F1D022040_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_F1D022040_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_f1d022053_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_f1d022053_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_f1d022053_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_f1d022123_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_f1d022123_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_f1d022123_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_f1d022150_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_f1d022150_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_f1d022150_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_f1d022156_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_f1d022156_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\03_f1d022156_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022075_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022075_2_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022075_3_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022079_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022079_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022079_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022082_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022082_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022082_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_f1d022085_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_f1d022085_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_f1d022085_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022092_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022092_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022092_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_f1d022109_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_f1d022109_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_f1d022109_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022135_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022135_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022135_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022136_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022136_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_F1D022136_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_f1d022155_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_f1d022155_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\04_f1d022155_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022010_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022010_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022010_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_f1d022029_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_f1d022029_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_f1d022029_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_f1d022091_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_f1d022091_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_f1d022091_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022093_1_1.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022093_1_2.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022093_1_3.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022095_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022095_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022095_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022108_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022108_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022108_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022161_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022161_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022161_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022163_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022163_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\05_F1D022163_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_F1D022017_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_F1D022017_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_F1D022017_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_f1d022062_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_f1d022062_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_f1d022062_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_F1D022067_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_F1D022067_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_F1D022067_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_f1d022068_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_f1d022068_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_f1d022068_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_F1D022076_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_F1D022076_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_F1D022076_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_f1d022105_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_f1d022105_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_f1d022105_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_F1D022113_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_F1D022113_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\06_F1D022113_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_f1d022011_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_f1d022011_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_f1d022011_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_f1d022056_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_f1d022056_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_f1d022056_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D022070_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D022070_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D022070_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D022083_1_1.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D022083_1_2.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D022083_1_3.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D022100_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D022100_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D022100_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_f1d22320016_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_f1d22320016_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_f1d22320016_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D22320022_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D22320022_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D22320022_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D22320023_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D22320023_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\07_F1D22320023_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022006_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022006_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022006_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022009_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022009_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022009_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022012_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022012_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022012_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022023_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022023_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022023_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022052_1_1.jpg.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022052_1_2.jpg.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022052_1_3.jpg.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022097_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022097_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022097_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022126_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022126_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022126_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022157_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022157_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\08_F1D022157_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022058_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022058_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022058_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022060_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022060_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022060_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022074_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022074_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022074_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_f1d022101_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_f1d022101_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_f1d022101_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022110_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022110_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022110_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022158_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022158_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\09_F1D022158_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022037_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022037_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022037_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022055_1_1.png
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022055_1_2.png
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022055_1_3.png
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022112_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022112_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022112_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022127_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022127_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022127_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022137_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022137_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022137_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022140_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022140_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022140_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022151_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022151_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1D022151_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1d022165_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1d022165_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\10_F1d022165_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022049_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022049_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022049_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022054_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022054_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022054_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022065_1_1.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022065_1_2.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022065_1_3.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022066_1.1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022066_1.2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022066_1.3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022131_1_1.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022131_1_2.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\11_F1D022131_1_3.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022019_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022019_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022019_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022041_1_1[1].jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022041_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022041_1_3[1].jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_f1d022043_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_f1d022043_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_f1d022043_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022096_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022096_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022096_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022098_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022098_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022098_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_f1d022116_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_f1d022116_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_f1d022116_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022138_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022138_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022138_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022142_1_1.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022142_1_2.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022142_1_3.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022145_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022145_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\12_F1D022145_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_f1d022038_1_1.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_f1d022038_1_2.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_f1d022038_1_3.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022045_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_f1d022045_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022045_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022048_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022048_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022048_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022077_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022077_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022077_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022143_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022143_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022143_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022146_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022146_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D022146_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D22320010_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D22320010_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_F1D22320010_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_f1d22320014_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_f1d22320014_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\13_f1d22320014_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022005_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022005_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022005_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022031_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022031_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022031_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022034_1_1.jpg.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022034_1_1_3.jpg.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022034_1_2.jpg.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022073_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022073_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022073_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_f1d022084_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_f1d022084_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_f1d022084_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022104_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022104_1_2.png
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_F1D022104_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_f1d022111_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_f1d022111_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_f1d022111_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_f1d022125_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_f1d022125_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\14_f1d022125_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022015_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022015_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022015_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022024_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022024_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022024_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022026_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022026_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022026_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022032_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022032_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022032_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_f1d022080_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_f1d022080_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_f1d022080_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022087_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022087_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022087_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_f1d022090_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_f1d022090_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_f1d022090_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022115_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022115_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022115_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022119_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022119_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\15_F1D022119_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022001_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022001_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022001_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_f1d022002_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_f1d022002_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_f1d022002_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_f1d0220152_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_f1d0220152_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_f1d0220152_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022061_1_1.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022061_1_2.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022061_1_3.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_f1d022081_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_f1d022081_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_f1d022081_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_f1d022081_1_4.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_f1d022081_1_5.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022153_1_1(1).jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022153_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022153_1_2(1).jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022153_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022153_1_3(1).jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022153_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022162_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022162_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D022162_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D22320004_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D22320004_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D22320004_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D22320012_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D22320012_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\16_F1D22320012_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022022_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022022_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022022_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022050_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022050_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022050_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022051_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022051_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022051_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022088_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022088_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022088_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_f1d022094_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_f1d022094_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_f1d022094_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022106_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022106_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022106_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022121_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022121_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022121_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022122_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022122_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\17_F1D022122_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022030_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022030_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022030_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022039_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022039_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022039_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_f1d022057_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_f1d022057_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_f1d022057_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022072_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022072_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022072_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022102_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022102_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022102_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022107_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022107_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022107_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022118_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022118_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022118_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022129_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022129_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\18_F1D022129_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\1_F1D22320020_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\3_F1D022014_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\3_F1D022014_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\3_F1D022014_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\6_F1D022059_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\6_F1D022059_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\6_F1D022059_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\7_F1D022144_1_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\7_F1D022144_1_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_1\7_F1D022144_1_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_F1D022016_2_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_F1D022016_2_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_F1D022016_2_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_F1D022044_2_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_F1D022044_2_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_F1D022044_2_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_F1D022069_2_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_F1D022069_2_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_F1D022069_2_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_f1d022103_2_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_f1d022103_2_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_f1d022103_2_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_f1d022120_2_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_f1d022120_2_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_f1d022120_2_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_2\01_f1d022149_2_1.jpg
# ...
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\13_F1D022143_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\13_F1D022143_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\13_F1D022143_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\13_F1D022146_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\13_F1D022146_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\13_F1D022146_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\13_f1d22320014_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\13_f1d22320014_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\13_f1d22320014_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_F1D022005_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_F1D022005_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_F1D022005_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_F1D022031_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_F1D022031_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_F1D022031_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_f1d022034_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_f1d022034_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_f1d022034_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_F1D022073_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_F1D022073_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_F1D022073_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_f1d022084_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_f1d022084_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_f1d022084_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_F1D022104_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_F1D022104_5_2.png
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_F1D022104_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_f1d022111_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_f1d022111_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_f1d022111_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_f1d022125_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_f1d022125_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\14_f1d022125_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022015_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022015_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022015_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022024_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022024_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022024_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022026_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022026_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022026_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022032_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022032_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022032_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_f1d022080_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_f1d022080_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_f1d022080_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022087_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022087_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022087_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_f1d022090_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_f1d022090_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_f1d022090_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022115_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022115_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022115_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022119_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022119_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\15_F1D022119_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D022001_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D022001_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D022001_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_f1d022002_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_f1d022002_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_f1d022002_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_f1d0220152_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_f1d0220152_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_f1d0220152_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D022061_5_1.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D022061_5_2.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D022061_5_3.jpeg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_f1d022081_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_f1d022081_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_f1d022081_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_f1d022081_5_4.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_f1d022081_5_5.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D022153_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D022153_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D022153_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D022162_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D022162_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D022162_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D22320004_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D22320004_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D22320004_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D22320012_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D22320012_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\16_F1D22320012_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022022_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022022_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022022_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022050_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022050_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022050_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022051_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022051_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022051_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022088_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022088_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022088_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_f1d022094_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_f1d022094_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_f1d022094_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022106_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022106_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022106_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022121_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022121_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022121_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022122_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022122_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\17_F1D022122_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022030_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022030_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022030_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022039_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022039_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022039_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_f1d022057_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_f1d022057_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_f1d022057_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022072_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022072_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022072_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022102_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022102_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022102_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022107_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022107_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022107_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022118_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022118_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022118_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022129_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022129_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\18_F1D022129_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\1_F1D22320020_5_5.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\3_F1D022014_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\3_F1D022014_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\3_F1D022014_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\6_F1D022059_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\6_F1D022059_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\6_F1D022059_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\7_F1D022144_5_1.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\7_F1D022144_5_2.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\7_F1D022144_5_3.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\IMG_20240523_184654.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\IMG_20240523_184659.jpg
# Resized image: C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger\finger_5\IMG_20240523_184704.jpg
# Resizing completed for all images.

# %%
def count_images(base_folder):
    folder_counts = {}
    for root, _, files in os.walk(base_folder):
        folder_name = os.path.basename(root)
        image_count = sum(1 for filename in files if filename.endswith(('.png', '.jpg', '.jpeg')))
        if image_count > 0:
            folder_counts[folder_name] = image_count
    return folder_counts

def plot_histogram(data, title, xlabel, ylabel):
    plt.figure(figsize=(10, 5))
    plt.bar(data.keys(), data.values())
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

folder_counts = count_images(base_folder)

plot_histogram(folder_counts, 'Jumlah Gambar per Kelas', 'Kelas (Subfolder)', 'Jumlah Gambar')

total_images = sum(folder_counts.values())
total_classes = len(folder_counts)

print(f'Total jumlah data (gambar): {total_images}')
print(f'Total jumlah kelas (subfolder): {total_classes}')
# Out:
# Total jumlah data (gambar): 2164
# Total jumlah kelas (subfolder): 5

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Data Augmentation

# %%
def resize_image(image, target_size=(150, 150)):
    return cv2.resize(image, target_size)

def rotate_image(image, angle):
    height, width = image.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((width/2, height/2), angle, 1)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
    return rotated_image

def shift_image(image, shift_x, shift_y):
    height, width = image.shape[:2]
    translation_matrix = np.float32([[1, 0, shift_x], [0, 1, shift_y]])
    shifted_image = cv2.warpAffine(image, translation_matrix, (width, height))
    return shifted_image

def zoom_image(image, scale):
    height, width = image.shape[:2]
    center_x, center_y = width // 2, height // 2
    scaled_width, scaled_height = int(width * scale), int(height * scale)
    start_x, start_y = center_x - scaled_width // 2, center_y - scaled_height // 2
    end_x, end_y = start_x + scaled_width, start_y + scaled_height
    zoomed_image = image[start_y:end_y, start_x:end_x]
    return zoomed_image

def flip_horizontal(image):
    return cv2.flip(image, 1)

def flip_vertical(image):
    return cv2.flip(image, 0)

input_folder = "C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger/finger_1"

image_files = [f for f in os.listdir(input_folder) if os.path.isfile(os.path.join(input_folder, f))]

num_images = 3

augmented_images = []

for file in image_files:
    image_path = os.path.join(input_folder, file)
    original_image = cv2.imread(image_path)
    for i in range(num_images):
            augmented_image = original_image.copy()

            augment_type = random.randint(1, 100)

            if 1 <= augment_type <= 20:
                angle = random.randint(-10, 10)
                augmented_image = rotate_image(augmented_image, angle)

            elif 21 <= augment_type <= 40:
                shift_x = random.randint(-10, 10)
                shift_y = random.randint(-10, 10)
                augmented_image = shift_image(augmented_image, shift_x, shift_y)

            elif 41 <= augment_type <= 60:
                scale = random.uniform(0.9, 1.1)
                augmented_image = zoom_image(augmented_image, scale)

            elif 61 <= augment_type <= 75:
                augmented_image = flip_horizontal(augmented_image)

            elif 76 <= augment_type <= 90:
                augmented_image = flip_vertical(augmented_image)

            elif 91 <= augment_type <= 100:
                angle = random.randint(-10, 10)
                augmented_image = rotate_image(augmented_image, angle)

                shift_x = random.randint(-10, 10)
                shift_y = random.randint(-10, 10)
                augmented_image = shift_image(augmented_image, shift_x, shift_y)

                scale = random.uniform(0.9, 1.1)
                augmented_image = zoom_image(augmented_image, scale)

                if random.random() < 0.5:
                    augmented_image = flip_horizontal(augmented_image)

                if random.random() < 0.5:
                    augmented_image = flip_vertical(augmented_image)

            augmented_image = resize_image(augmented_image)
            augmented_images.append(augmented_image)

augmented_images_array = np.array(augmented_images)

# %% [markdown]
# kode di atas merupakan proses data augmentasi yang berguna untuk membuat data lebih banyak dan bervariasi. Adapun fungsi fungsi yang digunakan dalam melakukan augmentasi data:
# 1. `resize_image`: Mengubah ukuran gambar sesuai dengan ukuran target yang diberikan.
# 2. `rotate_image`: Memutar gambar sebesar sudut yang ditentukan.
# 3. `shift_image`: Memindahkan gambar secara horizontal dan vertikal sesuai dengan nilai pergeseran yang diberikan.
# 4. `zoom_image`: Memperbesar atau memperkecil gambar sesuai dengan faktor skala yang diberikan.
# 5. `flip_horizontal` dan `flip_vertical`: Membalikkan gambar secara horizontal atau vertikal.
#
# langkah yang dilakukan untuk data augmentasi pertama mengiterasi melalui setiap file gambar dalam folder input.
# Untuk setiap gambar, kemudian membuat berapa banyak gambar diaugmentasi `num_images` dengan transformasi acak yang dipilih.
# Transformasi dipilih secara acak dengan menggunakan bilangan acak antara 1 dan 100 `augment_type`. Berbagai jenis augmentasi dipilih berdasarkan rentang nilai `augment_type`.
# Setiap gambar augmented kemudian diubah ukurannya menjadi ukuran yang ditentukan (default: 150x150) menggunakan fungsi `resize_image`.
# Gambar-gambar augmented disimpan dalam list `augmented_images`. Kemudian diubah menjadi array agar mudah di proses.

# %% [markdown]
# kode di bawah merupakan fungsi `show_images`digunakan untuk menampilkan gambar yang sudah di augmentasi. jumlah gambar yang ingin ditampilkan dapat diatur sesuai dengan `num_rows=10` dan `num_cols`

# %%
def show_images(images, num_rows=10, num_cols=5):
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(10,10))
    for i in range(num_rows):
        for j in range(num_cols):
            axes[i, j].imshow(cv2.cvtColor(images[i * num_cols + j], cv2.COLOR_BGR2RGB))
            axes[i, j].axis('off')
    plt.show()

show_images(augmented_images)

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# kode di bawah melakukan proses preprcessing. Pertama dengan menggunakan library cv2 untuk melakukan denoise dan proses deteksi tepi dengan cara menerapkan modul GaussianBlur untuk denoise dan canny untuk deteksi tepi. Kemudian membuat list gambar yang sudah di proses dengan nama `processed_images`, melakukan perulangan pda gambar yang sudah di augmentasi `augmented_images_array` untuk melakukan denoise dan deteksi tepi pada semua gambar kemudian di masukkan ke dalam list `processed_images`. Kemudian menampilkan gambar yang sudah di proses dengan fungsi `show_images`

# %%
def denoise_image(image):
    return cv2.GaussianBlur(image, (5, 5), 0)

def detect_edges(image):
    return cv2.Canny(image, 100, 200)

processed_images = []

for image in augmented_images_array:
    denoised_image = denoise_image(image)
    detected_image = detect_edges(denoised_image)
    
    processed_images.append(detected_image)

processed_images_array = np.array(processed_images)


show_images(processed_images)

# %% [markdown]
# ### Feature Extraction

# %%
def calculate_glcm(image, distances, angles):
    max_gray_level = 256
    glcm = np.zeros((max_gray_level, max_gray_level, len(distances), len(angles)), dtype=np.float64)
    
    for distance_index, distance in enumerate(distances):
        for angle_index, angle in enumerate(angles):
            for i in range(image.shape[0]):
                for j in range(image.shape[1]):
                    row_offset = int(np.round(np.sin(angle) * distance))
                    col_offset = int(np.round(np.cos(angle) * distance))
                    row = i + row_offset
                    col = j + col_offset
                    if row >= 0 and row < image.shape[0] and col >= 0 and col < image.shape[1]:
                        current_pixel = image[i, j]
                        neighbor_pixel = image[row, col]
                        glcm[current_pixel, neighbor_pixel, distance_index, angle_index] += 1
    
    glcm_sum = glcm.sum(axis=(0, 1), keepdims=True)
    glcm = glcm / glcm_sum
    return glcm

def calculate_glcm_properties(glcm):
    num_levels = glcm.shape[0]
    num_distances = glcm.shape[2]
    num_angles = glcm.shape[3]
    
    contrast = np.zeros((num_distances, num_angles))
    dissimilarity = np.zeros((num_distances, num_angles))
    homogeneity = np.zeros((num_distances, num_angles))
    energy = np.zeros((num_distances, num_angles))
    correlation = np.zeros((num_distances, num_angles))
    asm = np.zeros((num_distances, num_angles))
    entropy = np.zeros((num_distances, num_angles))
    
    for d in range(num_distances):
        for a in range(num_angles):
            glcm_slice = glcm[:, :, d, a]
            i, j = np.indices(glcm_slice.shape)
            
            contrast[d, a] = np.sum((i - j) ** 2 * glcm_slice)
            dissimilarity[d, a] = np.sum(np.abs(i - j) * glcm_slice)
            homogeneity[d, a] = np.sum(glcm_slice / (1 + np.abs(i - j)))
            energy[d, a] = np.sum(glcm_slice ** 2)
            asm[d, a] = energy[d, a]
            
            mean_i = np.sum(i * glcm_slice)
            mean_j = np.sum(j * glcm_slice)
            std_i = np.sqrt(np.sum((i - mean_i) ** 2 * glcm_slice))
            std_j = np.sqrt(np.sum((j - mean_j) ** 2 * glcm_slice))
            
            if std_i > 0 and std_j > 0:
                correlation[d, a] = np.sum((i - mean_i) * (j - mean_j) * glcm_slice) / (std_i * std_j)
            else:
                correlation[d, a] = 0
                
            entropy[d, a] = -np.sum(glcm_slice * np.log2(glcm_slice + (glcm_slice == 0)))
    
    return contrast, dissimilarity, homogeneity, energy, correlation, asm, entropy

features = []

angles = [0, 45, 90, 135]
distances = [1]

for idx, image in enumerate(processed_images):
    glcm = calculate_glcm(image, distances, angles)

    contrast, dissimilarity, homogeneity, energy, correlation, asm, entropy = calculate_glcm_properties(glcm)
    
    feature = {'image_index': idx}
    for angle_index, angle in enumerate([0, 45, 90, 135]):
        feature[f'contrast_{angle}'] = contrast[0, angle_index]
        feature[f'dissimilarity_{angle}'] = dissimilarity[0, angle_index]
        feature[f'homogeneity_{angle}'] = homogeneity[0, angle_index]
        feature[f'energy_{angle}'] = energy[0, angle_index]
        feature[f'correlation_{angle}'] = correlation[0, angle_index]
        feature[f'asm_{angle}'] = asm[0, angle_index]
        feature[f'entropy_{angle}'] = entropy[0, angle_index]
    
    features.append(feature)

features_df = pd.DataFrame(features)

output_csv_path = "csv_finger1/glcm_finger_1.csv"
features_df.to_csv(output_csv_path, index=False)

print(f"Fitur GLCM selesai diekstraksi")
# Out:
# Fitur GLCM selesai diekstraksi

# %% [markdown]
# Kode di atas melakukan ekstraksi fitur GLCM (Gray-Level Co-occurrence Matrix) dari gambar-gambar yang telah diproses sebelumnya.
#
# 1. Fungsi `calculate_glcm`:
# Fungsi ini menghitung matriks GLCM dari sebuah gambar. Matriks GLCM dihitung untuk setiap jarak `distance` dan sudut `angle` yang ditentukan. Untuk setiap piksel dalam gambar, diformulasikan jarak `row_offset` dan `col_offset` dan koordinat piksel tetangga yang sesuai. Piksel dan tetangga tersebut digunakan untuk mengupdate nilai GLCM. Hasil GLCM dinormalisasi dengan jumlah total entri dalam matriks.
#
# 2. Fungsi `calculate_glcm_properties`:
# Fungsi ini menghitung berbagai properti statistik dari matriks GLCM yang dihasilkan. Properti yang dihitung meliputi kontras, disimilaritas, homogenitas, energi, korelasi, ASM (Angular Second Moment), dan entropi.
# Setiap properti dihitung untuk setiap jarak dan sudut.
#
# 3. Loop untuk Ekstraksi Fitur:
# Skrip ini melakukan loop melalui setiap gambar yang telah diproses sebelumnya. Untuk setiap gambar, matriks GLCM dihitung menggunakan fungsi calculate_glcm.
# Properti GLCM diekstraksi menggunakan fungsi calculate_glcm_properties. Hasil fitur disimpan dalam sebuah list features.
#
# 4. Konversi ke DataFrame:
# Hasil fitur disimpan dalam bentuk DataFrame menggunakan `pd.DataFrame`. DataFrame ini kemudian disimpan dalam format CSV. Dengan cara ini, skrip ini menghasilkan dataset fitur GLCM yang dapat digunakan untuk melatih model pembelajaran mesin dalam berbagai tugas analisis citra atau pengenalan pola.

# %% [markdown]
# ### Features Selection

# %%
features_df = pd.read_csv("csv_finger1/glcm_finger_1.csv")

variance_threshold = 0.29
correlation_threshold = 0.8

variances = features_df.var()
selected_features_variance = variances[variances > variance_threshold].index
features_df_variance = features_df[selected_features_variance]

corr_matrix = features_df_variance.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

to_drop = [column for column in upper.columns if any(upper[column] > correlation_threshold)]
features_df_correlation = features_df_variance.drop(columns=to_drop)

output_csv_path_selected = "csv_finger1/glcm_features_selected_finger_1l.csv"
features_df_correlation.to_csv(output_csv_path_selected, index=False)

# %% [markdown]
# Kode di atas memuat DataFrame yang berisi fitur GLCM dari file CSV yang sebelumnya telah disimpan, kemudian melakukan seleksi fitur berdasarkan ambang batas varians dan ambang batas korelasi.
#
# 1. Seleksi Fitur Berdasarkan Varians:
# Varians dari setiap fitur dihitung menggunakan features_df.var(). Fitur yang memiliki varians di atas ambang batas (variance_threshold) dipilih. DataFrame baru features_df_variance dibuat hanya dengan fitur-fitur yang dipilih.
#
# 2. Seleksi Fitur Berdasarkan Korelasi:
# Matriks korelasi absolut dihitung menggunakan features_df_variance.corr().abs(). Bagian atas matriks korelasi diambil menggunakan np.triu(np.ones(corr_matrix.shape), k=1), karena matriks korelasi adalah simetris. Fitur-fitur yang memiliki korelasi di atas ambang batas (correlation_threshold) dengan fitur lainnya diidentifikasi dan dihapus. DataFrame baru features_df_correlation dibuat hanya dengan fitur-fitur yang dipilih setelah seleksi korelasi.
#
# Terakhir menyimpan DataFrame yang Dipilih. Dengan melakukan dua tahap seleksi fitur yang memungkinkan untuk mengurangi dimensi dari dataset fitur GLCM dan menghilangkan fitur-fitur yang memiliki korelasi tinggi dengan fitur lainnya.

# %% [markdown]
# ### Splitting Data

# %%
features_df = pd.read_csv("csv_finger1/glcm_features_selected_finger_1l.csv")

features = features_df.drop(columns=['image_index'])
labels = features_df['image_index']

data_combined = features.copy()
data_combined['label'] = labels

data_combined = data_combined.sample(frac=1, random_state=42).reset_index(drop=True)

train_ratio = 0.8
train_size = int(len(data_combined) * train_ratio)

train_data = data_combined[:train_size]
test_data = data_combined[train_size:]

X_train = train_data.drop(columns=['label'])
y_train = train_data['label']
X_test = test_data.drop(columns=['label'])
y_test = test_data['label']

X_train.to_csv("csv_finger1/X_train_1.csv", index=False)
X_test.to_csv("csv_finger1/X_test_1.csv", index=False)
y_train.to_csv("csv_finger1/y_train_1.csv", index=False)
y_test.to_csv("csv_finger1/y_test_1.csv", index=False)

print("Data telah selesai dibagi")
# Out:
# Data telah selesai dibagi

# %% [markdown]
# Pada kode di atas merupakan kode yang berfokus pada pemisahan data menjadi data latih dan data uji untuk keperluan pelatihan dan evaluasi model.
#
# 1. Memuat Data dari File CSV:
# DataFrame features_df dimuat dari file CSV yang berisi fitur GLCM yang telah dipilih sebelumnya.
#
# 2. Pemisahan Fitur dan Label:
# Fitur-fitur (kolom-kolom kecuali 'image_index') dan label (kolom 'image_index') dipisahkan ke dalam dua DataFrame terpisah. DataFrame features berisi fitur-fitur, sementara labels berisi label gambar (indeks gambar).
#
# 3. Penggabungan Data dan Pengacakan:
# Fitur-fitur dan label-label digabungkan menjadi satu DataFrame dengan menambahkan kolom 'label' yang berisi label-label.
# Data diacak dengan menggunakan metode .sample(frac=1) untuk memastikan bahwa data teracak dengan baik. Pengacakan dilakukan dengan menggunakan random_state=42 untuk menghasilkan hasilnya.
#
# 4. Pemisahan Data Latih dan Data Uji:
# Ukuran data latih ditentukan berdasarkan rasio yang telah ditetapkan sebelumnya (train_ratio), dan data uji akan menjadi sisa data setelah data latih diambil. DataFrame dipecah menjadi train_data dan test_data berdasarkan ukuran data latih yang telah ditentukan sebelumnya.
#
# 5. Pemisahan Fitur dan Label untuk Data Latih dan Data Uji:
# DataFrame-dataFrame yang telah dipisahkan (train_data dan test_data) kemudian dibagi lagi menjadi fitur (X) dan label (y) untuk data latih dan data uji. Dan yang terakhir menyimpan Data sebagai File CSV
#
# Dengan langkah-langkah yang sudah dilakukan, data telah disiapkan untuk digunakan dalam pelatihan dan evaluasi model.

# %% [markdown]
# ### Normalization

# %%
X_train = pd.read_csv("csv_finger1/X_train_1.csv")
X_test = pd.read_csv("csv_finger1/X_test_1.csv")
y_train = pd.read_csv("csv_finger1/y_train_1.csv")
y_test = pd.read_csv("csv_finger1/y_test_1.csv")


def min_max_scaling(df):
    return (df - df.min()) / (df.max() - df.min())

X_train_normalized = min_max_scaling(X_train)
X_test_normalized = min_max_scaling(X_test)
y_train_normalized = min_max_scaling(y_train)
y_test_normalized = min_max_scaling(y_test)

X_train_normalized.to_csv("csv_finger1/X_train_normalized_1.csv", index=False)
X_test_normalized.to_csv("csv_finger1/X_test_normalized_1.csv", index=False)
y_train_normalized.to_csv("csv_finger1/y_train_normalized_1.csv", index=False)
y_test_normalized.to_csv("csv_finger1/y_test_normalized_1.csv", index=False)

print("Data telah selesai dinormalisasi")
# Out:
# Data telah selesai dinormalisasi

# %% [markdown]
# Dalam bagian ini, kode melakukan normalisasi data menggunakan metode Min-Max Scaling sebelum menyimpannya kembali ke file CSV.
# 1. Memuat Data dari File CSV:
# DataFrame X_train, X_test, y_train, dan y_test dimuat dari file CSV yang sesuai.
#
# 2. Fungsi Min-Max Scaling:
# Fungsi `min_max_scaling` didefinisikan untuk melakukan normalisasi Min-Max Scaling pada DataFrame yang diberikan. Normalisasi Min-Max Scaling dilakukan dengan mengurangi nilai minimum dari setiap kolom dan membagi hasilnya dengan selisih nilai maksimum dan minimum dari setiap kolom. Ini akan menghasilkan nilai antara 0 dan 1.
#
# 3. Normalisasi Data:
# Setiap DataFrame di-normalisasi menggunakan fungsi `min_max_scaling`. X_train, X_test, y_train, dan y_test dinormalisasi masing-masing.
#
# Terakhir menyimpan Data yang Dinormalisasi sebagai File CSV. Dengan normalisasi ini, setiap fitur dan label telah diubah sehingga nilainya berada dalam rentang yang seragam, memudahkan proses pelatihan model dan mencegah dominasi fitur-fitur dengan skala yang besar.

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Evaluation
