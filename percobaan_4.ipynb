# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import pandas as pd

# %% [markdown]
# Import library
# 1. OpenCV = digunakan untuk pengolahan citra dan visi komputer.
# 2. Matplotlib = digunakan untuk visualisasi data dalam Python.
# 3. NumPy = digunakan untuk komputasi numerik.
# 4. Modul os = menyediakan fungsi-fungsi yang berinteraksi dengan sistem operasi.
# 5. Modul random = digunakan untuk menghasilkan bilangan acak.
# 6. Pandas = digunakan untuk analisis data struktural dalam Python.

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Data Augmentation

# %%
def resize_image(image, target_size=(150, 150)):
    return cv2.resize(image, target_size)

def rotate_image(image, angle):
    height, width = image.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((width/2, height/2), angle, 1)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
    return rotated_image

def shift_image(image, shift_x, shift_y):
    height, width = image.shape[:2]
    translation_matrix = np.float32([[1, 0, shift_x], [0, 1, shift_y]])
    shifted_image = cv2.warpAffine(image, translation_matrix, (width, height))
    return shifted_image

def zoom_image(image, scale):
    height, width = image.shape[:2]
    center_x, center_y = width // 2, height // 2
    scaled_width, scaled_height = int(width * scale), int(height * scale)
    start_x, start_y = center_x - scaled_width // 2, center_y - scaled_height // 2
    end_x, end_y = start_x + scaled_width, start_y + scaled_height
    zoomed_image = image[start_y:end_y, start_x:end_x]
    return zoomed_image

def flip_horizontal(image):
    return cv2.flip(image, 1)

def flip_vertical(image):
    return cv2.flip(image, 0)

input_folder = "C:/Users/YURAKI/PCD/praktikum/modul-6-jurnal-Rifkyy29/finger/finger_4"

image_files = [f for f in os.listdir(input_folder) if os.path.isfile(os.path.join(input_folder, f))]

num_images = 3

augmented_images = []

for file in image_files:
    image_path = os.path.join(input_folder, file)
    original_image = cv2.imread(image_path)
    for i in range(num_images):
            augmented_image = original_image.copy()

            augment_type = random.randint(1, 100)

            if 1 <= augment_type <= 20:
                angle = random.randint(-10, 10)
                augmented_image = rotate_image(augmented_image, angle)

            elif 21 <= augment_type <= 40:
                shift_x = random.randint(-10, 10)
                shift_y = random.randint(-10, 10)
                augmented_image = shift_image(augmented_image, shift_x, shift_y)

            elif 41 <= augment_type <= 60:
                scale = random.uniform(0.9, 1.1)
                augmented_image = zoom_image(augmented_image, scale)

            elif 61 <= augment_type <= 75:
                augmented_image = flip_horizontal(augmented_image)

            elif 76 <= augment_type <= 90:
                augmented_image = flip_vertical(augmented_image)

            elif 91 <= augment_type <= 100:
                angle = random.randint(-10, 10)
                augmented_image = rotate_image(augmented_image, angle)

                shift_x = random.randint(-10, 10)
                shift_y = random.randint(-10, 10)
                augmented_image = shift_image(augmented_image, shift_x, shift_y)

                scale = random.uniform(0.9, 1.1)
                augmented_image = zoom_image(augmented_image, scale)

                if random.random() < 0.5:
                    augmented_image = flip_horizontal(augmented_image)

                if random.random() < 0.5:
                    augmented_image = flip_vertical(augmented_image)

            augmented_image = resize_image(augmented_image)
            augmented_images.append(augmented_image)

augmented_images_array = np.array(augmented_images)

# %% [markdown]
# kode di atas merupakan proses data augmentasi yang berguna untuk membuat data lebih banyak dan bervariasi. Adapun fungsi fungsi yang digunakan dalam melakukan augmentasi data:
# 1. `resize_image`: Mengubah ukuran gambar sesuai dengan ukuran target yang diberikan.
# 2. `rotate_image`: Memutar gambar sebesar sudut yang ditentukan.
# 3. `shift_image`: Memindahkan gambar secara horizontal dan vertikal sesuai dengan nilai pergeseran yang diberikan.
# 4. `zoom_image`: Memperbesar atau memperkecil gambar sesuai dengan faktor skala yang diberikan.
# 5. `flip_horizontal` dan `flip_vertical`: Membalikkan gambar secara horizontal atau vertikal.
#
# langkah yang dilakukan untuk data augmentasi pertama mengiterasi melalui setiap file gambar dalam folder input.
# Untuk setiap gambar, kemudian membuat berapa banyak gambar diaugmentasi `num_images` dengan transformasi acak yang dipilih.
# Transformasi dipilih secara acak dengan menggunakan bilangan acak antara 1 dan 100 `augment_type`. Berbagai jenis augmentasi dipilih berdasarkan rentang nilai `augment_type`.
# Setiap gambar augmented kemudian diubah ukurannya menjadi ukuran yang ditentukan (default: 150x150) menggunakan fungsi `resize_image`.
# Gambar-gambar augmented disimpan dalam list `augmented_images`. Kemudian diubah menjadi array agar mudah di proses.

# %% [markdown]
# kode di bawah merupakan fungsi `show_images`digunakan untuk menampilkan gambar yang sudah di augmentasi. jumlah gambar yang ingin ditampilkan dapat diatur sesuai dengan `num_rows=10` dan `num_cols`

# %%
def show_images(images, num_rows=10, num_cols=5):
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(10,10))
    for i in range(num_rows):
        for j in range(num_cols):
            axes[i, j].imshow(cv2.cvtColor(images[i * num_cols + j], cv2.COLOR_BGR2RGB))
            axes[i, j].axis('off')
    plt.show()

show_images(augmented_images)

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# kode di bawah melakukan proses preprcessing. Pertama dengan menggunakan library cv2 untuk melakukan denoise dan proses grayscaling dengan cara menerapkan modul GaussianBlur untuk denoise dan cvtColor untuk grayscaling. Kemudian membuat list gambar yang sudah di proses dengan nama `processed_images`, melakukan perulangan pda gambar yang sudah di augmentasi `augmented_images_array` untuk melakukan denoise dan grayscaling pada semua gambar kemudian di masukkan ke dalam list `processed_images`. Kemudian menampilkan gambar yang sudah di proses dengan fungsi `show_images`

# %%
def denoise_image(image):
    return cv2.GaussianBlur(image, (5, 5), 0)

def grayscale(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    return gray_image

processed_images = []

for image in augmented_images_array:
    grayscale_image = grayscale(image)
    
    processed_images.append(grayscale_image)

processed_images_array = np.array(processed_images)


show_images(processed_images)

# %% [markdown]
# ### Feature Extraction

# %%
def calculate_glcm(image, distances, angles):
    max_gray_level = 256
    glcm = np.zeros((max_gray_level, max_gray_level, len(distances), len(angles)), dtype=np.float64)
    
    for distance_index, distance in enumerate(distances):
        for angle_index, angle in enumerate(angles):
            for i in range(image.shape[0]):
                for j in range(image.shape[1]):
                    row_offset = int(np.round(np.sin(angle) * distance))
                    col_offset = int(np.round(np.cos(angle) * distance))
                    row = i + row_offset
                    col = j + col_offset
                    if row >= 0 and row < image.shape[0] and col >= 0 and col < image.shape[1]:
                        current_pixel = image[i, j]
                        neighbor_pixel = image[row, col]
                        glcm[current_pixel, neighbor_pixel, distance_index, angle_index] += 1
    
    glcm_sum = glcm.sum(axis=(0, 1), keepdims=True)
    glcm = glcm / glcm_sum
    return glcm

def calculate_glcm_properties(glcm):
    num_levels = glcm.shape[0]
    num_distances = glcm.shape[2]
    num_angles = glcm.shape[3]
    
    contrast = np.zeros((num_distances, num_angles))
    dissimilarity = np.zeros((num_distances, num_angles))
    homogeneity = np.zeros((num_distances, num_angles))
    energy = np.zeros((num_distances, num_angles))
    correlation = np.zeros((num_distances, num_angles))
    asm = np.zeros((num_distances, num_angles))
    entropy = np.zeros((num_distances, num_angles))
    
    for d in range(num_distances):
        for a in range(num_angles):
            glcm_slice = glcm[:, :, d, a]
            i, j = np.indices(glcm_slice.shape)
            
            contrast[d, a] = np.sum((i - j) ** 2 * glcm_slice)
            dissimilarity[d, a] = np.sum(np.abs(i - j) * glcm_slice)
            homogeneity[d, a] = np.sum(glcm_slice / (1 + np.abs(i - j)))
            energy[d, a] = np.sum(glcm_slice ** 2)
            asm[d, a] = energy[d, a]
            
            mean_i = np.sum(i * glcm_slice)
            mean_j = np.sum(j * glcm_slice)
            std_i = np.sqrt(np.sum((i - mean_i) ** 2 * glcm_slice))
            std_j = np.sqrt(np.sum((j - mean_j) ** 2 * glcm_slice))
            
            if std_i > 0 and std_j > 0:
                correlation[d, a] = np.sum((i - mean_i) * (j - mean_j) * glcm_slice) / (std_i * std_j)
            else:
                correlation[d, a] = 0
                
            entropy[d, a] = -np.sum(glcm_slice * np.log2(glcm_slice + (glcm_slice == 0)))
    
    return contrast, dissimilarity, homogeneity, energy, correlation, asm, entropy

features = []

angles = [0, 45, 90, 135]
distances = [1]

for idx, image in enumerate(processed_images):
    glcm = calculate_glcm(image, distances, angles)

    contrast, dissimilarity, homogeneity, energy, correlation, asm, entropy = calculate_glcm_properties(glcm)
    
    feature = {'image_index': idx}
    for angle_index, angle in enumerate([0, 45, 90, 135]):
        feature[f'contrast_{angle}'] = contrast[0, angle_index]
        feature[f'dissimilarity_{angle}'] = dissimilarity[0, angle_index]
        feature[f'homogeneity_{angle}'] = homogeneity[0, angle_index]
        feature[f'energy_{angle}'] = energy[0, angle_index]
        feature[f'correlation_{angle}'] = correlation[0, angle_index]
        feature[f'asm_{angle}'] = asm[0, angle_index]
        feature[f'entropy_{angle}'] = entropy[0, angle_index]
    
    features.append(feature)

features_df = pd.DataFrame(features)

output_csv_path = "csv_finger4/glcm_finger_4.csv"
features_df.to_csv(output_csv_path, index=False)

print(f"Fitur GLCM selesai diekstraksi")
# Out:
# Fitur GLCM selesai diekstraksi

# %% [markdown]
# Kode di atas melakukan ekstraksi fitur GLCM (Gray-Level Co-occurrence Matrix) dari gambar-gambar yang telah diproses sebelumnya.
#
# 1. Fungsi `calculate_glcm`:
# Fungsi ini menghitung matriks GLCM dari sebuah gambar. Matriks GLCM dihitung untuk setiap jarak `distance` dan sudut `angle` yang ditentukan. Untuk setiap piksel dalam gambar, diformulasikan jarak `row_offset` dan `col_offset` dan koordinat piksel tetangga yang sesuai. Piksel dan tetangga tersebut digunakan untuk mengupdate nilai GLCM. Hasil GLCM dinormalisasi dengan jumlah total entri dalam matriks.
#
# 2. Fungsi `calculate_glcm_properties`:
# Fungsi ini menghitung berbagai properti statistik dari matriks GLCM yang dihasilkan. Properti yang dihitung meliputi kontras, disimilaritas, homogenitas, energi, korelasi, ASM (Angular Second Moment), dan entropi.
# Setiap properti dihitung untuk setiap jarak dan sudut.
#
# 3. Loop untuk Ekstraksi Fitur:
# Skrip ini melakukan loop melalui setiap gambar yang telah diproses sebelumnya. Untuk setiap gambar, matriks GLCM dihitung menggunakan fungsi calculate_glcm.
# Properti GLCM diekstraksi menggunakan fungsi calculate_glcm_properties. Hasil fitur disimpan dalam sebuah list features.
#
# 4. Konversi ke DataFrame:
# Hasil fitur disimpan dalam bentuk DataFrame menggunakan `pd.DataFrame`. DataFrame ini kemudian disimpan dalam format CSV. Dengan cara ini, skrip ini menghasilkan dataset fitur GLCM yang dapat digunakan untuk melatih model pembelajaran mesin dalam berbagai tugas analisis citra atau pengenalan pola.

# %% [markdown]
# ### Features Selection

# %%
features_df = pd.read_csv("csv_finger4/glcm_finger_4.csv")

variance_threshold = 0.29
correlation_threshold = 0.8

variances = features_df.var()
selected_features_variance = variances[variances > variance_threshold].index
features_df_variance = features_df[selected_features_variance]

corr_matrix = features_df_variance.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

to_drop = [column for column in upper.columns if any(upper[column] > correlation_threshold)]
features_df_correlation = features_df_variance.drop(columns=to_drop)

output_csv_path_selected = "csv_finger4/glcm_features_selected_finger_4l.csv"
features_df_correlation.to_csv(output_csv_path_selected, index=False)

# %% [markdown]
# Kode di atas memuat DataFrame yang berisi fitur GLCM dari file CSV yang sebelumnya telah disimpan, kemudian melakukan seleksi fitur berdasarkan ambang batas varians dan ambang batas korelasi.
#
# 1. Seleksi Fitur Berdasarkan Varians:
# Varians dari setiap fitur dihitung menggunakan features_df.var(). Fitur yang memiliki varians di atas ambang batas (variance_threshold) dipilih. DataFrame baru features_df_variance dibuat hanya dengan fitur-fitur yang dipilih.
#
# 2. Seleksi Fitur Berdasarkan Korelasi:
# Matriks korelasi absolut dihitung menggunakan features_df_variance.corr().abs(). Bagian atas matriks korelasi diambil menggunakan np.triu(np.ones(corr_matrix.shape), k=1), karena matriks korelasi adalah simetris. Fitur-fitur yang memiliki korelasi di atas ambang batas (correlation_threshold) dengan fitur lainnya diidentifikasi dan dihapus. DataFrame baru features_df_correlation dibuat hanya dengan fitur-fitur yang dipilih setelah seleksi korelasi.
#
# Terakhir menyimpan DataFrame yang Dipilih. Dengan melakukan dua tahap seleksi fitur yang memungkinkan untuk mengurangi dimensi dari dataset fitur GLCM dan menghilangkan fitur-fitur yang memiliki korelasi tinggi dengan fitur lainnya.

# %% [markdown]
# ### Splitting Data

# %%
features_df = pd.read_csv("csv_finger4/glcm_features_selected_finger_4l.csv")

features = features_df.drop(columns=['image_index'])
labels = features_df['image_index']

data_combined = features.copy()
data_combined['label'] = labels

data_combined = data_combined.sample(frac=1, random_state=42).reset_index(drop=True)

train_ratio = 0.8
train_size = int(len(data_combined) * train_ratio)

train_data = data_combined[:train_size]
test_data = data_combined[train_size:]

X_train = train_data.drop(columns=['label'])
y_train = train_data['label']
X_test = test_data.drop(columns=['label'])
y_test = test_data['label']

X_train.to_csv("csv_finger4/X_train_4.csv", index=False)
X_test.to_csv("csv_finger4/X_test_4.csv", index=False)
y_train.to_csv("csv_finger4/y_train_4.csv", index=False)
y_test.to_csv("csv_finger4/y_test_4.csv", index=False)

print("Data telah selesai dibagi")
# Out:
# Data telah selesai dibagi

# %% [markdown]
# Pada kode di atas merupakan kode yang berfokus pada pemisahan data menjadi data latih dan data uji untuk keperluan pelatihan dan evaluasi model.
#
# 1. Memuat Data dari File CSV:
# DataFrame features_df dimuat dari file CSV yang berisi fitur GLCM yang telah dipilih sebelumnya.
#
# 2. Pemisahan Fitur dan Label:
# Fitur-fitur (kolom-kolom kecuali 'image_index') dan label (kolom 'image_index') dipisahkan ke dalam dua DataFrame terpisah. DataFrame features berisi fitur-fitur, sementara labels berisi label gambar (indeks gambar).
#
# 3. Penggabungan Data dan Pengacakan:
# Fitur-fitur dan label-label digabungkan menjadi satu DataFrame dengan menambahkan kolom 'label' yang berisi label-label.
# Data diacak dengan menggunakan metode .sample(frac=1) untuk memastikan bahwa data teracak dengan baik. Pengacakan dilakukan dengan menggunakan random_state=42 untuk menghasilkan hasilnya.
#
# 4. Pemisahan Data Latih dan Data Uji:
# Ukuran data latih ditentukan berdasarkan rasio yang telah ditetapkan sebelumnya (train_ratio), dan data uji akan menjadi sisa data setelah data latih diambil. DataFrame dipecah menjadi train_data dan test_data berdasarkan ukuran data latih yang telah ditentukan sebelumnya.
#
# 5. Pemisahan Fitur dan Label untuk Data Latih dan Data Uji:
# DataFrame-dataFrame yang telah dipisahkan (train_data dan test_data) kemudian dibagi lagi menjadi fitur (X) dan label (y) untuk data latih dan data uji. Dan yang terakhir menyimpan Data sebagai File CSV
#
# Dengan langkah-langkah yang sudah dilakukan, data telah disiapkan untuk digunakan dalam pelatihan dan evaluasi model.

# %% [markdown]
# ### Normalization

# %%
X_train = pd.read_csv("csv_finger4/X_train_4.csv")
X_test = pd.read_csv("csv_finger4/X_test_4.csv")
y_train = pd.read_csv("csv_finger4/y_train_4.csv")
y_test = pd.read_csv("csv_finger4/y_test_4.csv")


def min_max_scaling(df):
    return (df - df.min()) / (df.max() - df.min())

X_train_normalized = min_max_scaling(X_train)
X_test_normalized = min_max_scaling(X_test)
y_train_normalized = min_max_scaling(y_train)
y_test_normalized = min_max_scaling(y_test)

X_train_normalized.to_csv("csv_finger4/X_train_normalized_4.csv", index=False)
X_test_normalized.to_csv("csv_finger4/X_test_normalized_4.csv", index=False)
y_train_normalized.to_csv("csv_finger4/y_train_normalized_4.csv", index=False)
y_test_normalized.to_csv("csv_finger4/y_test_normalized_4.csv", index=False)

print("Data telah selesai dinormalisasi")
# Out:
# Data telah selesai dinormalisasi

# %% [markdown]
# Dalam bagian ini, kode melakukan normalisasi data menggunakan metode Min-Max Scaling sebelum menyimpannya kembali ke file CSV.
# 1. Memuat Data dari File CSV:
# DataFrame X_train, X_test, y_train, dan y_test dimuat dari file CSV yang sesuai.
#
# 2. Fungsi Min-Max Scaling:
# Fungsi `min_max_scaling` didefinisikan untuk melakukan normalisasi Min-Max Scaling pada DataFrame yang diberikan. Normalisasi Min-Max Scaling dilakukan dengan mengurangi nilai minimum dari setiap kolom dan membagi hasilnya dengan selisih nilai maksimum dan minimum dari setiap kolom. Ini akan menghasilkan nilai antara 0 dan 1.
#
# 3. Normalisasi Data:
# Setiap DataFrame di-normalisasi menggunakan fungsi `min_max_scaling`. X_train, X_test, y_train, dan y_test dinormalisasi masing-masing.
#
# Terakhir menyimpan Data yang Dinormalisasi sebagai File CSV. Dengan normalisasi ini, setiap fitur dan label telah diubah sehingga nilainya berada dalam rentang yang seragam, memudahkan proses pelatihan model dan mencegah dominasi fitur-fitur dengan skala yang besar.

# %% [markdown]
# ## Modeling

# %%
X_train = pd.read_csv("csv_finger4/X_train_normalized_4.csv").values
X_test = pd.read_csv("csv_finger4/X_test_normalized_4.csv").values
y_train = pd.read_csv("csv_finger4/y_train_normalized_4.csv").values.flatten()
y_test = pd.read_csv("csv_finger4/y_test_normalized_4.csv").values.flatten()

def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

def knn(X_train, y_train, X_test, k=3):
    predictions = []
    for test_point in X_test:
        distances = []
        for i, train_point in enumerate(X_train):
            distance = euclidean_distance(test_point, train_point)
            distances.append((distance, y_train[i]))
        distances.sort(key=lambda x: x[0])
        neighbors = distances[:k]
        neighbor_labels = [label for _, label in neighbors]
        most_common_label = max(set(neighbor_labels), key=neighbor_labels.count)
        predictions.append(most_common_label)
    return predictions

k = 10

y_pred = knn(X_train, y_train, X_test, k)

print("Modeling selesai.")
# Out:
# Modeling selesai.

# %% [markdown]
# Kode di atas mengimplementasikan algoritma k-Nearest Neighbors (k-NN) untuk klasifikasi data yang telah dinormalisasi sebelumnya.
#
# 1. Memuat Data dari File CSV yang Telah Dinormalisasi:
# DataFrame yang telah dinormalisasi sebelumnya dimuat dari file CSV dan diubah menjadi array NumPy.
#
# 2. Membuat fungsi Euclidean Distance:
# Fungsi `euclidean_distance` didefinisikan untuk menghitung jarak Euclidean antara dua titik dalam ruang fitur.
#
# 3. Algoritma k-NN:
# Fungsi knn diimplementasikan untuk melakukan klasifikasi dengan algoritma k-NN. Untuk setiap titik uji dalam X_test, jarak Euclidean dihitung terhadap semua titik latih dalam X_train. Jarak-jarak dan label-labelnya disimpan dalam sebuah list distances. List distances diurutkan berdasarkan jarak, dan k-nearest neighbors (k tetangga terdekat) diambil. Label-label dari k tetangga terdekat diambil, dan label yang paling umum di antara mereka dipilih sebagai prediksi untuk titik uji tersebut.
#
# Terakhir, fungsi knn dipanggil dengan parameter X_train, y_train, X_test, dan nilai k yang telah ditentukan sebelumnya. Hasil prediksi disimpan dalam y_pred.
# Dengan ini,telah dilakukan mplementasi dan penggunaan algoritma k-NN untuk melakukan klasifikasi pada dataset yang telah disiapkan.

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Kode dibawah mendefinisikan dua fungsi untuk mengevaluasi kinerja model klasifikasi:
#
# 1. Fungsi accuracy:
# Fungsi ini menghitung akurasi dari prediksi model. Akurasi didefinisikan sebagai jumlah prediksi yang benar dibagi dengan total jumlah prediksi.
#
# 2. Fungsi classification_report:
# Fungsi ini menghasilkan laporan klasifikasi yang mencakup metrik evaluasi seperti presisi (precision), recall, dan F1-score untuk setiap kelas, serta metrik rata-rata tertimbang (weighted average) dari presisi, recall, dan F1-score.
#
# Untuk setiap kelas,
# presisi dihitung sebagai rasio true positive dibagi dengan jumlah true positive dan false positive. Presisi mengukur seberapa akurat model dalam mengidentifikasi kelas positif.
#
# Recall dihitung sebagai rasio true positive dibagi dengan jumlah true positive dan false negative. Recall mengukur seberapa baik model dalam menangkap semua instance dari kelas yang benar positif.
#
# F1-score dihitung sebagai rasio harmonis dari presisi dan recall.
# Metrik-metrik ini dihitung untuk setiap kelas dalam data, dan juga dihitung nilai rata-rata tertimbang dari metrik-metrik tersebut untuk semua kelas.
#
# support digunakan menghitung jumlah instance dalam kelas yang diprediksi sebagai positif (true positive + false positive).
#
# Hasil laporan klasifikasi disusun dalam bentuk dictionary.
#
# Terakhir fungsi fungsi tersebut digunakan untuk mengevaluasi prediksi yang dihasilkan oleh model k-NN. Hasil evaluasi, termasuk akurasi dan laporan klasifikasi, kemudian dicetak.

# %%
def accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / len(y_true)

def classification_report(y_true, y_pred):
    labels = np.unique(y_true)
    report = {}
    for label in labels:
        true_positive = np.sum((y_true == label) & (y_pred == label))
        false_positive = np.sum((y_true != label) & (y_pred == label))
        false_negative = np.sum((y_true == label) & (y_pred != label))
        true_negative = np.sum((y_true != label) & (y_pred != label))
        
        precision = true_positive / (true_positive + false_positive) if (true_positive + false_positive) > 0 else 0
        recall = true_positive / (true_positive + false_negative) if (true_positive + false_negative) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        
        support = np.sum(y_true == label)
        
        report[label] = {
            "precision": precision,
            "recall": recall,
            "f1_score": f1_score,
            "support": support
        }
    
    avg_precision = np.sum([report[label]['precision'] * report[label]['support'] for label in labels]) / len(y_true)
    avg_recall = np.sum([report[label]['recall'] * report[label]['support'] for label in labels]) / len(y_true)
    avg_f1_score = np.sum([report[label]['f1_score'] * report[label]['support'] for label in labels]) / len(y_true)
    
    report['weighted avg'] = {
        "precision": avg_precision,
        "recall": avg_recall,
        "f1_score": avg_f1_score,
        "support": len(y_true)
    }
    
    return report

acc = accuracy(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Akurasi: {acc}")
print("Classification Report:")
for label, metrics in report.items():
    print(f"Label {label}:")
    for metric, value in metrics.items():
        print(f"  {metric}: {value:.2f}")

print("Evaluasi selesai.")
# Out:
# Akurasi: 0.0
# Classification Report:
# Label 0.0:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0054137664346481:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0092807424593967:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0100541376643464:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0116009280742459:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0146945088940448:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0154679040989945:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0193348801237432:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.025522041763341:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0278422273781902:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0301624129930394:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0402165506573859:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0487238979118329:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0665119876256767:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0696055684454756:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0726991492652745:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0750193348801237:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0788863109048723:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0858468677494199:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0928074245939675:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.0935808197989172:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.099767981438515:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.102861562258314:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1098221191028615:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1121423047177107:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1152358855375096:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1160092807424593:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1167826759474091:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1206496519721577:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1229698375870069:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1237432327919566:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1276102088167053:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1430781129156999:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1438515081206496:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1453982985305491:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1515854601701469:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1539056457849961:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1546790409899458:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1554524361948956:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1577726218097447:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1585460170146945:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1593194122196442:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1662799690641918:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.168600154679041:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1732405259087393:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1763341067285382:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.177107501933488:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.185614849187935:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1894818252126836:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.194122196442382:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.1948955916473317:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2018561484918793:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2072699149265274:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2126836813611755:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2150038669760247:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2180974477958236:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2219644238205723:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2258313998453209:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2273781902552204:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.242846094354215:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2443928847641144:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2544470224284609:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.259860788863109:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2645011600928074:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2660479505027069:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2915699922660479:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2923433874709977:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2962103634957463:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.296983758700696:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.2985305491105955:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3016241299303944:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3023975251353442:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3062645011600928:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.308584686774942:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3093580819798917:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3101314771848414:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3109048723897912:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3132250580046403:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3225058004640371:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.337200309358082:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3402938901778809:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3488012374323279:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3511214230471771:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.354215003866976:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3573085846867749:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3596287703016241:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3619489559164733:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3642691415313225:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.365815931941222:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3673627223511214:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3735498839907192:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3766434648105182:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.379737045630317:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3874709976798144:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3921113689095127:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3928847641144625:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.3936581593194122:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4013921113689095:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4044856921887084:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4168600154679041:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4215003866976025:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4245939675174014:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4292343387470997:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4338747099767981:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4346481051817478:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4354215003866976:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4361948955916473:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.445475638051044:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4524361948955916:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.45707656612529:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4632637277648878:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4694508894044857:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4725444702242846:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4810518174787316:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4841453982985305:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4880123743232792:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4934261407579273:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.494199535962877:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4949729311678267:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4957463263727765:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4980665119876257:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4988399071925754:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.4996133023975251:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5003866976024749:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5081206496519721:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5088940448569219:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5119876256767208:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.525908739365816:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5274555297757154:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5297757153905646:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5305491105955144:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5390564578499614:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.539829853054911:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5421500386697602:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5475638051044084:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5552977571539056:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.559938128383604:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.563031709203403:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5730858468677494:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.576952822892498:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5777262180974478:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5784996133023975:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.580046403712297:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5893271461716937:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5916473317865429:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5939675174013921:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5986078886310905:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.5993812838360402:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6017014694508894:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6109822119102861:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6133023975251354:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6140757927300851:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6156225831399845:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6179427687548337:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6210363495746326:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6218097447795824:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6295436968290796:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.634184068058778:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6419180201082754:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6450116009280742:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6488785769528229:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6597061098221191:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6612529002320185:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6643464810518175:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6666666666666666:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6720804331013148:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6728538283062645:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6774941995359629:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6782675947409126:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.679814385150812:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6821345707656613:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6883217324052591:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6921887084300077:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.6929621036349575:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7053364269141531:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7169373549883991:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7177107501933488:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7347254447022429:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.737045630317092:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7378190255220418:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7385924207269915:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7393658159319412:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7409126063418406:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7416860015467904:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7509667440061871:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7532869296210364:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7579273008507347:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.768754833720031:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7819025522041764:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7834493426140758:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7849961330239753:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.785769528228925:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7873163186388245:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7880897138437741:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7888631090487239:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.7919566898685229:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.794276875483372:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8020108275328693:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8066511987625676:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8074245939675174:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8120649651972158:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8159319412219644:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8182521268368136:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8190255220417634:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8221191028615623:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8236658932714617:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8275328692962104:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.831399845320959:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8360402165506574:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8391337973704563:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8422273781902552:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.843000773395205:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8460943542150039:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8530549110595514:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8569218870843001:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8584686774941995:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8631090487238979:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8677494199535963:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8692962103634957:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8700696055684455:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8723897911832946:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8731631863882444:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8778035576179428:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.880123743232792:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8816705336426914:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8839907192575406:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8894044856921887:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8901778808971385:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8917246713070379:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.8979118329466357:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9040989945862336:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.905645784996133:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9110595514307812:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9118329466357308:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9149265274555298:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.917246713070379:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9180201082753288:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.920340293890178:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9218870843000774:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.925754060324826:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9280742459396752:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9334880123743232:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9381283836040216:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9389017788089714:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9419953596287703:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9443155452436196:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9450889404485692:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.945862335653519:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.948182521268368:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9497293116782676:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9535962877030162:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9566898685228152:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9590100541376644:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9752513534416086:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.977571539056458:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9783449342614076:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.9860788863109048:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.988399071925754:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 0.993812838360402:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label 1.0:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 1.00
# Label weighted avg:
#   precision: 0.00
#   recall: 0.00
#   f1_score: 0.00
#   support: 260.00
# Evaluasi selesai.
